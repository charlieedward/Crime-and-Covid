# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import requests
import json
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, Dropdown

# %%
URL = "https://dsci551-final-project-fd95f-default-rtdb.firebaseio.com/"
json_suffix = '.json'

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Loading and Remove Irrelevant Features

# %%
# crime data
# 2020-01-01~2021-08-16
crime_data = pd.read_csv("/Users/Charlie/Desktop/USC/課程/DSCI551/Project/data/Crime_Data_from_2020_to_Present.csv")
crime_data.drop(['Date Rptd', 'Rpt Dist No' , 'Crm Cd', 'Part 1-2', 'Mocodes', 'Crm Cd 1', 
                 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street', 'LOCATION'], axis=1, inplace=True)

# %%
crime_data.head()
# Out:
#        DR_NO                DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468  01/08/2020 12:00:00 AM      2230     3    Southwest
# 1  190101086  01/01/2020 12:00:00 AM       330     1      Central
# 2  201220752  09/16/2020 12:00:00 AM      1230    12  77th Street
# 3  191501505  01/01/2020 12:00:00 AM      1730    15  N Hollywood
# 4  191921269  01/01/2020 12:00:00 AM       415    19      Mission
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0                           BATTERY - SIMPLE ASSAULT        36        F
# 1                           BATTERY - SIMPLE ASSAULT        25        M
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        62        M
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76        F
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31        X
#
#   Vict Descent  Premis Cd                                   Premis Desc  \
# 0            B      501.0                        SINGLE FAMILY DWELLING
# 1            H      102.0                                      SIDEWALK
# 2            B      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3            W      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 4            X      409.0                           BEAUTY SUPPLY STORE
#
#    Weapon Used Cd                                     Weapon Desc Status  \
# 0           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO
# 1           500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 2             NaN                                             NaN     IC
# 3             NaN                                             NaN     IC
# 4             NaN                                             NaN     IC
#
#    Status Desc      LAT       LON
# 0  Adult Other  34.0141 -118.2978
# 1  Invest Cont  34.0459 -118.2545
# 2  Invest Cont  33.9739 -118.2630
# 3  Invest Cont  34.1685 -118.4019
# 4  Invest Cont  34.2198 -118.4468

# %%
# covid_data
# 2020-03-10~2021-10-03
covid_data = pd.read_csv('/Users/Charlie/Desktop/USC/課程/DSCI551/Project/code/Final/LA_County_Covid19_tests_date_table.csv')
covid_data.drop(['Unnamed: 0'], axis=1, inplace=True)
covid_data = covid_data.dropna()
covid_data.head()
# Out:
#     date_use  cumulative_tests  cumulative_tests_pos  \
# 0  2021/10/2          31283474               1740508
# 1  2021/10/1          31282660               1740479
# 2  2021/9/30          31215633               1739696
# 3  2021/9/29          31085474               1738360
# 4  2021/9/28          30929493               1736773
#
#   percent_positive_tests_cum   tests  tests_pos percent_positive_tests  \
# 0                      5.60%     814         29                  3.60%
# 1                      5.60%   67027        783                  1.20%
# 2                      5.60%  130159       1336                     1%
# 3                      5.60%  155981       1587                     1%
# 4                      5.60%  131566       1526                  1.20%
#
#    avg_tests  avg_pos_tests percent_positive_avg_tests
# 0    87437.0         1110.0                      1.30%
# 1    91997.0         1265.0                      1.40%
# 2   106554.0         1396.0                      1.30%
# 3   116476.0         1443.0                      1.20%
# 4   120689.0         1482.0                      1.20%

# %%
covid_data['percent_positive_tests_cum'] = covid_data['percent_positive_tests_cum'].str.rstrip('%').astype('float') / 100.0
covid_data['percent_positive_tests'] = covid_data['percent_positive_tests'].str.rstrip('%').astype('float') / 100.0
covid_data['percent_positive_avg_tests'] = covid_data['percent_positive_avg_tests'].str.rstrip('%').astype('float') / 100.0

# %%
covid_data.head()
# Out:
#     date_use  cumulative_tests  cumulative_tests_pos  \
# 0  2021/10/2          31283474               1740508
# 1  2021/10/1          31282660               1740479
# 2  2021/9/30          31215633               1739696
# 3  2021/9/29          31085474               1738360
# 4  2021/9/28          30929493               1736773
#
#    percent_positive_tests_cum   tests  tests_pos  percent_positive_tests  \
# 0                       0.056     814         29                   0.036
# 1                       0.056   67027        783                   0.012
# 2                       0.056  130159       1336                   0.010
# 3                       0.056  155981       1587                   0.010
# 4                       0.056  131566       1526                   0.012
#
#    avg_tests  avg_pos_tests  percent_positive_avg_tests
# 0    87437.0         1110.0                       0.013
# 1    91997.0         1265.0                       0.014
# 2   106554.0         1396.0                       0.013
# 3   116476.0         1443.0                       0.012
# 4   120689.0         1482.0                       0.012

# %%
crime_data.columns
# Out:
# Index(['DR_NO', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Crm Cd Desc',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'LAT', 'LON'],
#       dtype='object')

# %%
covid_data.columns
# Out:
# Index(['date_use', 'cumulative_tests', 'cumulative_tests_pos',
#        'percent_positive_tests_cum', 'tests', 'tests_pos',
#        'percent_positive_tests', 'avg_tests', 'avg_pos_tests',
#        'percent_positive_avg_tests'],
#       dtype='object')

# %% [markdown]
# ### Data Transforming

# %%
# Convert to DataTime Format
crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])
covid_data['date_use'] = pd.to_datetime(covid_data['date_use'])
# Rename Columns Name
crime_data.rename(columns={'DATE OCC': 'date','TIME OCC':'crime_time', 'AREA':'area', 'AREA NAME':'area_name',
                           'CRIME_TIME':'crime_time', 'LAT':'lat', 'LON':'lon','Vict Age':'vict_age',
                           'Vict Descent':'vict_des','Vict Sex':'vict_sex','Weapon Used Cd':'weapon'}, inplace=True)
covid_data.rename(columns={'date_use': 'date'}, inplace=True)

# %%
crime_data['year'] = crime_data['date'].dt.year
crime_data['month'] = crime_data['date'].dt.month
crime_data['day'] = crime_data['date'].dt.day
covid_data['year'] = covid_data['date'].dt.year
covid_data['month'] = covid_data['date'].dt.month
covid_data['day'] = covid_data['date'].dt.day

# %%
crime_data.head()
# Out:
#        DR_NO       date  crime_time  area    area_name  \
# 0   10304468 2020-01-08        2230     3    Southwest
# 1  190101086 2020-01-01         330     1      Central
# 2  201220752 2020-09-16        1230    12  77th Street
# 3  191501505 2020-01-01        1730    15  N Hollywood
# 4  191921269 2020-01-01         415    19      Mission
#
#                                          Crm Cd Desc  vict_age vict_sex  \
# 0                           BATTERY - SIMPLE ASSAULT        36        F
# 1                           BATTERY - SIMPLE ASSAULT        25        M
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        62        M
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76        F
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31        X
#
#   vict_des  Premis Cd                                   Premis Desc  weapon  \
# 0        B      501.0                        SINGLE FAMILY DWELLING   400.0
# 1        H      102.0                                      SIDEWALK   500.0
# 2        B      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     NaN
# 3        W      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     NaN
# 4        X      409.0                           BEAUTY SUPPLY STORE     NaN
#
#                                       Weapon Desc Status  Status Desc  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO  Adult Other
# 1                     UNKNOWN WEAPON/OTHER WEAPON     IC  Invest Cont
# 2                                             NaN     IC  Invest Cont
# 3                                             NaN     IC  Invest Cont
# 4                                             NaN     IC  Invest Cont
#
#        lat       lon  year  month  day
# 0  34.0141 -118.2978  2020      1    8
# 1  34.0459 -118.2545  2020      1    1
# 2  33.9739 -118.2630  2020      9   16
# 3  34.1685 -118.4019  2020      1    1
# 4  34.2198 -118.4468  2020      1    1

# %%
# Merge Data
#data = pd.merge(crime_data, covid_data, how='outer', on='DATE')
#data.sort_values(by='DATE', key=pd.to_datetime).reset_index(drop=True)

# %% [markdown]
# ## Function Definition

# %%
def clean_database():
    response = requests.delete(URL + json_suffix)

# %%
def unique_date(dataframe):
    unique_date = dataframe['date'].unique()
    unique_date.sort()
    unique_dateList = list(dataframe['date'].unique())
    unique_dateList = np.datetime_as_string(unique_date, unit='D')
    return unique_dateList

# %%
def transform_to_json(df):
    json = df.to_json(orient = 'records')
    return json

# %%
def upload_data(url, index, year, month, date, data):
    try:
        database_URL = url + index + '/' + str(year) + '/' + str(month) + '/' + date  + json_suffix
        response = requests.put(database_URL, data)
    except:
        print("Upload Failed")

# %%
def upload_to_firebase(dataset, index):
    for year in dataset['year'].unique():
        df_year = dataset.loc[dataset['year']==year]
        for month in df_year['month'].unique():
            df_month = df_year.loc[df_year['month']==month]
            unique_dateList = unique_date(df_month)
            for i in unique_dateList:
                date = str(i)
                df = df_month.loc[df_month['date']==date]
                df.drop(['date'], axis=1)
                json_data = transform_to_json(df)
                upload_data(URL, index, year, month, date, json_data)

# %% [markdown]
# ## Running

# %%
clean_database()

# %%
upload_to_firebase(crime_data ,'crime')

# %%
upload_to_firebase(covid_data ,'covid')

# %%
crime_data.to_csv('crime_data_modified.csv', index=False)

# %%
covid_data.to_csv('covid_modified.csv', index=False)
